# %%
import numpy as np
arr=np.array([[-1,2,0,4],[4,-0.5,6,0],[2,6,7,6],[3,-7,4,2]])
print("Original array:\n",arr)
# Out:
# Original array:
#  [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.   6.   7.   6. ]
#  [ 3.  -7.   4.   2. ]]

# %%
cond=arr>2
temp=arr[cond]
print("\nElements greater than 2")
print(temp)
# Out:
# Elements greater than 2
# [4. 4. 6. 6. 7. 6. 3. 4.]
