# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaiyavarsha/numpy2/blob/main/240901122_pandasLoad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
d=pd.read_csv("/content/employees details.csv")
print(d)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
#Get the column heading
df=pd.DataFrame(d)
print("Column",df.columns)
# Out:
# Column Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
#Get the shape-(no.of rows, no.of columns)
print(df.shape)
# Out:
# (100, 11)

# %%
print("Mother's Maiden Name",df["Mother's Maiden Name"])
# Out:
# Mother's Maiden Name 0        Lewis
# 1        Perry
# 2       Taylor
# 3        Allen
# 4       Nelson
#         ...
# 95       Hayes
# 96       Smith
# 97         Lee
# 98    Peterson
# 99    Robinson
# Name: Mother's Maiden Name, Length: 100, dtype: object

# %%
#Extract/slice the table values [including this row,exculding this row]
print(df[4:10])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 4  193819         Mr.   Benjamin              R   Russell      M
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
# 9  162402        Hon.      Diana              T  Peterson      F
#
#                          E Mail      Father's Name       Mother's Name  \
# 4  benjamin.russell@charter.net    Gregory Russell   Elizabeth Russell
# 5        patrick.bailey@aol.com       Ralph Bailey        Laura Bailey
# 6            nancy.baker@bp.com        Scott Baker          Judy Baker
# 7        carol.murphy@gmail.com      Eugene Murphy    Katherine Murphy
# 8       frances.young@gmail.com         Fred Young       Lillian Young
# 9  diana.peterson@hotmail.co.uk  Jonathan Peterson  Christina Peterson
#
# ...

# %%
#Get the particular row values-through row number identification
print("Particular person details",df.loc[7])
# Out:
# Particular person details Emp ID                                  380086
# Name Prefix                               Mrs.
# First Name                               Carol
# Middle Initial                               V
# Last Name                               Murphy
# Gender                                       F
# E Mail                  carol.murphy@gmail.com
# Father's Name                    Eugene Murphy
# Mother's Name                 Katherine Murphy
# Mother's Maiden Name                  Peterson
# Salary                                   60918
# Name: 7, dtype: object

# %%
#Get the particularrow values- through 'Salary' identification
print(d.loc[d['Salary']==197537])
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 17  214352         Ms.    Theresa              G       Lee      F
#
#                    E Mail Father's Name Mother's Name Mother's Maiden Name  \
# 17  theresa.lee@gmail.com      John Lee   Rebecca Lee               Turner
#
#     Salary
# 17  197537

# %%
#Instead of company employ dataset we can use empoly salary list dataset.if the average of total salary is required use this code.
#Make an averageof total salary
df=d['Salary']/100
print("\nMske an average of total salary:\n",df)
# Out:
# Mske an average of total marks:
#  0     1682.51
# 1      510.63
# 2      501.55
# 3     1802.94
# 4     1176.42
#        ...
# 95    1297.74
# 96    1561.94
# 97     956.73
# 98     510.15
# 99     936.50
# Name: Salary, Length: 100, dtype: float64
